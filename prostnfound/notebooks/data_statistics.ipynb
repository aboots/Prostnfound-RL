# %%
from medAI.datasets.optimum.utils import get_cleaned_ua_metadata_table
from medAI.datasets.nct2013.data_access import data_accessor

tab = get_cleaned_ua_metadata_table()

tab.grade_group.value_counts()
# Out:
# grade_group
# 0.0    732
# 1.0    156
# 2.0    118
# 3.0     59
# 4.0     43
# 5.0     15
# Name: count, dtype: int64

# %%
tab
# Out:
#            center patient_id isBiopsy  ...   age   psa          study_arm
# core_id                                ...
# UA-003-005     UA     UA-003     True  ...  64.0  11.5   Arm3-MicroUS-MRI
# UA-003-006     UA     UA-003     True  ...  64.0  11.5   Arm3-MicroUS-MRI
# UA-003-007     UA     UA-003     True  ...  64.0  11.5   Arm3-MicroUS-MRI
# UA-003-008     UA     UA-003     True  ...  64.0  11.5   Arm3-MicroUS-MRI
# UA-003-009     UA     UA-003     True  ...  64.0  11.5   Arm3-MicroUS-MRI
# ...           ...        ...      ...  ...   ...   ...                ...
# UA-167-014     UA     UA-167     True  ...  60.0   7.9  Arm1-MicroUS-Only
# UA-167-015     UA     UA-167     True  ...  60.0   7.9  Arm1-MicroUS-Only
# UA-167-016     UA     UA-167     True  ...  60.0   7.9  Arm1-MicroUS-Only
# UA-167-017     UA     UA-167     True  ...  60.0   7.9  Arm1-MicroUS-Only
# UA-167-018     UA     UA-167     True  ...  60.0   7.9  Arm1-MicroUS-Only
#
# [1124 rows x 36 columns]

# %%
len(tab['patient_id'].unique())
# Out:
# 77

# %%
len(tabl[''])
# Out:
# isBiopsy
# True    1123
# Name: count, dtype: int64

# %%
from medAI.datasets.nct2013.data_access import data_accessor

data_accessor.get_metadata_table().groupby('center')['grade_group'].value_counts()
# Out:
# center  grade_group
# CRCEO   0.0            1255
#         2.0             119
#         3.0              51
#         4.0              32
#         5.0              12
# JH      0.0             568
#         3.0              19
#         2.0              13
#         4.0              10
#         5.0               6
# PCC     0.0            1400
#         2.0             121
#         3.0              41
#         4.0              23
#         5.0              14
# PMCC    0.0             486
#         2.0              75
#         3.0              15
#         4.0              12
# UVA     0.0            2018
#         2.0             152
#         3.0              69
#         4.0              57
#         5.0              39
# Name: count, dtype: int64

# %%
data_accessor.get_metadata_table()['grade_group'].value_counts()
# Out:
# grade_group
# 0.0    5727
# 2.0     480
# 3.0     195
# 4.0     134
# 5.0      71
# Name: count, dtype: int64
