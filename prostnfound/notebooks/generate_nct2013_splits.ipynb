# %%
import json
from medAI.datasets.nct2013.cohort_selection import select_cohort

trian, val, test = select_cohort(
    test_center="CRCEO", 
    exclude_benign_cores_from_positive_patients=True, 
    involvement_threshold_pct=40, 
    undersample_benign_ratio=6, 
)

with open('splits.json', 'w') as f: 
    json.dump(dict(train=trian, val=val, test=test), f)
# Out:
# INFO:root:Using test center CRCEO
